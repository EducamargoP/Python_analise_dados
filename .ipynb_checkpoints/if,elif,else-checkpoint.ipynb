# %%
idade_joao = 19
idade_maria = 20

# %%
if (idade_joao > idade_maria):
    print("jão e mais velho")
else:
    print("Maria e mais velha")
# Out:
# Maria e mais velha

# %%
idade_joao = 19
idade_maria = 20
idade_pedro = 30

# %%
if (idade_joao > idade_maria and idade_joao > idade_pedro):
    print("João e mais velho")
elif (idade_maria > idade_joao and idade_maria > idade_pedro):
    print("Maria e mais velha")
else:
    print("Pedro e mais velho")
# Out:
# Pedro e mais velho

# %%
# criança, adolecente, adulto

# %%
idade = 18

# %%
if ( idade <= 10):
    print ("AINDA E CRIANÇA")
elif (idade <= 11):
    print ("PRÉ ADOLECENTE")
elif (idade <= 12 and idade > 18):
    print ("ADOLECENTE")
elif (idade <= 18 and idade > 60):
    print("ADULTO")
elif (idade <= 60):
    print ("IDOSO")
# Out:
# ADULTO
