# %%
cadastro = {'nome': 'joão', 'idade':'30', 'sexo':'masculino'}

# %%
cadastro
# Out:
# {'nome': 'joão', 'idade': '30', 'sexo': 'masculino'}

# %%
type(cadastro)
# Out:
# dict

# %%
cadastro['nome']
# Out:
# 'joão'

# %%
#metodos do dicionario

# %%
'joão' in cadastro
# Out:
# False

# %%
'joão' in cadastro.values()
# Out:
# True

# %%
'nome' in cadastro
# Out:
# True

# %%
'nome' in cadastro.keys()
# Out:
# True

# %%
#Alterando valores do dicionario

# %%
cadastro['nome'] = 'Pedro'

# %%
cadastro
# Out:
# {'nome': 'Pedro', 'idade': '30', 'sexo': 'masculino'}

# %%
#adicionar valores

# %%
cadastro['Altura'] = 1.75

# %%
cadastro
# Out:
# {'nome': 'Pedro', 'idade': '30', 'sexo': 'masculino', 'Altura': 1.75}

# %%
#tirando valores

# %%
del (cadastro['sexo'])

# %%
cadastro
# Out:
# {'nome': 'Pedro', 'idade': '30', 'Altura': 1.75}

# %%
#copiando dicionairos diferença do igual para copy e que mexendo no igual voce deixa ambos igual, e copy ele copy so no momento que foi copiado

# %%
cadastro
# Out:
# {'nome': 'Pedro', 'idade': '30', 'Altura': 1.75}

# %%
cadastro_igual = cadastro

# %%
copia = cadastro.copy()

# %%
#juntando dicionarios

# %%
meus_contatos = {'nome': 'joão', 'tel':'999999999'}

# %%
seus_contatos = {'nome': 'caio', 'tel':'422222222'}

# %%
meus_contatos.update(seus_contatos)

# %%
meus_contatos
# Out:
# {'nome': 'caio',
#  'idade': '40',
#  'sexo': 'masculino',
#  'altura': '1.65',
#  'tel': '422222222'}
