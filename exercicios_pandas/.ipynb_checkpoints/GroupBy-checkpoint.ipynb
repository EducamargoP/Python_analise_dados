# %%
import pandas as pd
import numpy as np

# %%
data = {'SEDE':['SP','SP','MG','MG','RJ','RJ','ES','ES'],'VENDEDOR':['JORGE','ANA','THIAGO','PEDRO','RAFAEL','GUTO','MARIA','CAROL'],'VENDAS':[2000,2500,3100,1200,1500,3900,2900,3900]}
df = pd.DataFrame(data)

# %%
arrays = [['SÃO PAULO','SÃO PAULO','RIO DE JANEIRO', 'RIO DE JANEIRO', 'MINAS GERAIS', 'MINAS GERAIS'],['GARRAFAS','COPOS','GARRAFAS','COPOS','GARRAFAS','COPOS']]
index = pd.MultiIndex.from_arrays(arrays, names=('ESTADO','PRODUTO'))

# %%
df1 = pd.DataFrame({'TOTAL VENDIDO R$':[10000,35000,22400,12890,10880,13900]},index=index)

# %%
df
# Out:
#   SEDE VENDEDOR  VENDAS
# 0   SP    JORGE    2000
# 1   SP      ANA    2500
# 2   MG   THIAGO    3100
# 3   MG    PEDRO    1200
# 4   RJ   RAFAEL    1500
# 5   RJ     GUTO    3900
# 6   ES    MARIA    2900
# 7   ES    CAROL    3900

# %%
df.groupby('SEDE')

# %%
by_Sede = df.groupby('SEDE')

# %%
by_Sede.max()
# Out:
#      VENDEDOR  VENDAS
# SEDE
# ES      MARIA    3900
# MG     THIAGO    3100
# RJ     RAFAEL    3900
# SP      JORGE    2500

# %%
by_Sede.min()
# Out:
#      VENDEDOR  VENDAS
# SEDE
# ES      CAROL    2900
# MG      PEDRO    1200
# RJ       GUTO    1500
# SP        ANA    2000

# %%
df
# Out:
#   SEDE VENDEDOR  VENDAS
# 0   SP    JORGE    2000
# 1   SP      ANA    2500
# 2   MG   THIAGO    3100
# 3   MG    PEDRO    1200
# 4   RJ   RAFAEL    1500
# 5   RJ     GUTO    3900
# 6   ES    MARIA    2900
# 7   ES    CAROL    3900

# %%
df1
# Out:
#                          TOTAL VENDIDO R$
# ESTADO         PRODUTO
# SÃO PAULO      GARRAFAS             10000
#                COPOS                35000
# RIO DE JANEIRO GARRAFAS             22400
#                COPOS                12890
# MINAS GERAIS   GARRAFAS             10880
#                COPOS                13900
