# %%
import pandas as pd
import numpy as np

# %%
#series a partir de uma lista

# %%
lista = [10,20,30,40,50]

# %%
pd.Series(lista)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#series a partir de um dicionario

# %%
dicionario = {'tel':'99999', 'tel2':'111111','tel3':'222222'}

# %%
pd.Series(dicionario)
# Out:
# tel      99999
# tel2    111111
# tel3    222222
# dtype: str

# %%
#series a partir de um array

# %%
arr = np.array([10,20,30,40,50])

# %%
series3 = pd.Series(arr)

# %%
series3
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
series4 = pd.Series([10,20,30,40,50])

# %%
series4
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
lista = [100,200,300,400, 500]

# %%
series4 = pd.Series(lista)

# %%
series4
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
# ALTERANDO nome dos indices de numero para nomes
series5 = pd.Series([1,2,3,4], index=['br','eua','art','chile'])

# %%
series5
# Out:
# br       1
# eua      2
# art      3
# chile    4
# dtype: int64

# %%
lista = [1,2,3,4]
labels = ['BR', 'USA','ARGETINA', 'chile']

# %%
series6 = pd.Series([1,2,3,4],index=['BR', 'USA','ARGETINA', 'chile'])

# %%
series6
# Out:
# BR          1
# USA         2
# ARGETINA    3
# chile       4
# dtype: int64

# %%
#concatenação de tabelas
# usando o sinal de + exemplo series6 + series5
